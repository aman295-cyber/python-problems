# %%
# age group categorization
age=int(input("Enter the age"))
if age<13:
    print("child")
elif age<20:
    print("Teenager")
elif age<60:
    print("Adult")
else:
    print("senior")
# Out:
# Enter the age 56
# Adult

# %%
#Program to check The largest of three number

a=int(input("Enter 1st Number"))
b=int(input("Enter 2nd Number"))
c=int(input("Enter 3rd Number"))

if a>b and a>c:
    print("The Largest Number is ",a)
elif b>a and b>c:
    print("The Largest Number is ",b)
else:
    print("The Largest Number is ",c)
# Out:
# Enter 1st Number 555
# Enter 2nd Number 677
# Enter 3rd Number 45
# The Largest Number is  677

# %%
#Reverse a number without reversing function

num=int(input("Enter a number"))
reversed_number=0
while num>0:
    digit=num % 10
    reversed_number=reversed_number*10 + digit
    num=num//10
print("Reversed_number is ",reversed_number)
# Out:
# Enter a number 45678
# Reversed_number is  87654

# %%
# program to check pallindrome
num=int(input("Enter a number"))
temp=num
reversed_number=0
while num>0:
    digit=num % 10
    reversed_number=reversed_number*10 + digit
    num=num//10
if temp==reversed_number:
    print("Pallindrome")
else:
    print("Not Pallindrome")
# Out:
# Enter a number 6789876
# Pallindrome

# %%
# Sum of even number
n=10
sum=0
for i in range(1, n+1):
    if n%2==0:
        sum+=i
print(sum)
# Out:
# 55

# %%
# Multiplication Table

num=3
for i in range(1, 11):
    print(num,'x',i,'=',num*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
# reverse a string using loop

string='python'
rev_str=""

for char in string:
    rev_str=char+rev_str
print(rev_str)
# Out:
# nohtyp

# %%
#Simple interest
p=float(input("Enter principal amount="))
r=float(input("Enter rate of interest="))
t=float(input("Enter time(in years)="))

SI=(p*r*t)/100
print("Simple Interest=",SI)
# Out:
# Enter principal amount= 25000
# Enter rate of interest= 4
# Enter time(in years)= 5
# Simple Interest= 5000.0

# %%
#compound Interest
p=float(input("Enter principal amount="))
r=float(input("Enter rate of interest="))
t=float(input("Enter time(in years)="))

amount=p*(1 + r/100) **t
CI= amount - p
print("Compound Interest=",CI)
print("total amount=", amount)
# Out:
# Enter principal amount= 25000
# Enter rate of interest= 4
# Enter time(in years)= 5
# Compound Interest= 5416.322560000004
# total amount= 30416.322560000004

# %%
#### menu driven calculator
a=int(input("Enter First number:"))
b=int(input("Enter Second number:"))

print("1.Add 2.Sub 3.Mul 4.Div")
ch=int(input("choice:"))

if ch==1:
    print(a+b)
elif ch==2:
    print(a-b)
elif ch==3:
    print(a*b)
elif ch==4:
    if b!=0:
        print(a/b)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Input")
# Out:
# Enter First number: 56
# Enter Second number: 78
# 1.Add 2.Sub 3.Mul 4.Div
# choice: 3
# 4368

# %%
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y
def div(x,y):
    return x/y 

a=int(input("Enter First number:"))
b=int(input("Enter Second number:"))

print("1.Add 2.Sub 3.Mul 4.Div")
ch=int(input("choice:"))

if ch==1:
    print("Result:",add(a,b))
elif ch==2:
    print("Result:",sub(a,b))
elif ch==3:
    print("Result:",mul(a,b))
elif ch==4:
    if b!=0:
       print("Result:",div(a,b))
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Input")
# Out:
# Enter First number: 45
# Enter Second number: 67
# 1.Add 2.Sub 3.Mul 4.Div
# choice: 3
# Result: 3015

# %%
#Arithmetic operation
a=int(input("Enter First number:"))
b=int(input("Enter Second number:"))

print("Addition:" ,(a+b))
print("Subtraction:" ,(a-b))
print("Multiplication:" ,(a*b))

if b!=0:
    print("Division:" ,(a/b))
else:
     print("Division by zero is not allowed")
# Out:
# Enter First number: 78
# Enter Second number: 90
# Addition: 168
# Subtraction: -12
# Multiplication: 7020
# Division: 0.8666666666666667

# %%
#Armstrong number
n=int(input("Enter a number:"))
temp=n
arm_num=0
while n>0:
    digit=n % 10
    arm_num=arm_num + digit*digit*digit
    n=n//10

if temp==arm_num:
    print("Armstrong Number:" , arm_num)
else:
    print("This is not Armstrong number")

# %%
flower=[1,2,3,4]
for _ in flower:
    print(_)
# Out:
# 1
# 2
# 3
# 4

# %%
num=int(input("Enter number: ")) 
if num>1: 
    for i in range(2,num): 
        if num%i==0: 
            print("Prime") 
            break 
    else: 
        print("not Prime")
# Out:
# Enter number:  67
# not Prime

# %%
marks=[80,70,90] 
marks.append(85) 
marks[1]=75 
marks.remove(90) 
print(marks)
# Out:
# [80, 75, 85]

# %%
emp={"ID":101,"Name":"Shashank","Salary":50000} 
print(emp)
# Out:
# {'ID': 101, 'Name': 'Shashank', 'Salary': 50000}

# %%
emps={101:"Rahul",102:"Aman"} 
id=int(input("Enter ID: ")) 
print(emps.get(id,"Not found"))
# Out:
# Enter ID:  102
# Aman

# %%
emp={"Rahul":50000,"Aman":40000,"Neha":60000} 
sorted_emp=sorted(emp.items(),key=lambda x:x[1]) 
print(sorted_emp)
# Out:
# [('Aman', 40000), ('Rahul', 50000), ('Neha', 60000)]
